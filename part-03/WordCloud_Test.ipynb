# %%
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('../resources/Brazilian_retail/ecommerce_review_score.csv',
                 lineterminator='\n', usecols=['review_comment_message'])

# %%
text = " ".join([message for message in df['review_comment_message'] if message != 'no_message'])
text_mask = np.array(Image.open('image/e.jpg'))

# %%
def transform_format(val):
    if i == 0:
        return 255
    else:
        return i

# %%
transformed_mask = np.ndarray((text_mask.shape[0], text_mask.shape[1]), np.int32)

for i in range(len(text_mask)):
    transformed_mask[i] = list(map(transform_format, text_mask[i]))

# %%
# Create a word cloud image
wc = WordCloud(background_color=None, mode="RGBA", max_words=100, mask=text_mask)
               #contour_width=6, contour_color='rgba(0,0,0,1)')

# Generate a wordcloud
wc.generate(text)

# store to file
wc.to_file("image/ecommerce.png")

# show
plt.figure(figsize=[8,6])
plt.imshow(wc, interpolation='bilinear') #'bilinear')
plt.axis("off")
plt.show()
